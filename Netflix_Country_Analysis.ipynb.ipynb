# %% [markdown]
# # Task 3 - Country Wise Netflix Content Analysis
#
# ## Objective
# Analyze Netflix content availability across different countries.
#
# ## Tools Used
# - Python
# - Pandas
# - Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Netflix_Cleaned.csv")

df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
country = df['country'].dropna().str.split(', ').explode()

print(country.head())
# Out:
# 0    United States
# 1           France
# 2    United States
# 3           Brazil
# 4    United States
# Name: country, dtype: object

# %%
top_countries = country.value_counts().head(10)

print(top_countries)
# Out:
# country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
# Canada             271
# Japan              259
# South Korea        214
# France             213
# Spain              182
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
top_countries.plot(kind='bar')

plt.title("Top 10 Countries by Netflix Content")
plt.xlabel("Country")
plt.ylabel("Number of Titles")

plt.show()

# %%
print("Business Insights:")
print("1. Identified top content producing countries.")
print("2. Compared Netflix content availability across countries.")
print("3. Analyzed geographic distribution of content.")
# Out:
# Business Insights:
# 1. Identified top content producing countries.
# 2. Compared Netflix content availability across countries.
# 3. Analyzed geographic distribution of content.
